# %%
import cosmology_amilly.linear_growth as lg
import numpy as np
import matplotlib.pyplot as plt


red_shifts = np.linspace(12, 0, 3000)
D_Standard = lg.Linear_Growth_Factor(red_shifts, 1, 0, 0, 0)
D_Lambda = lg.Linear_Growth_Factor(red_shifts, 0.3, 0, 0.7, 0)
D_Open = lg.Linear_Growth_Factor(red_shifts, 0.3, 0, 0, 0.7)

plt.plot(1 + red_shifts, D_Standard, label="Standard CDM")
plt.plot(1 + red_shifts, D_Lambda, label="$\\Lambda$CDM")
plt.plot(1 + red_shifts, D_Open, label="Open CDM")

plt.xlabel("$1 + z$")
plt.ylabel("Linear Growth Factor $D(z)$")
plt.xscale("log")
plt.yscale("log")
plt.xlim(1, 11)
plt.ylim(0.09, 1.05)

plt.tick_params(axis="both", direction="in", length=8, width=1.5, top=True, right=True)
plt.tick_params(
    which="minor", direction="in", length=3, width=0.5, top=True, right=True
)
plt.grid(which="major", alpha=0.5)
plt.grid(which="minor", alpha=0.3)
plt.title("Linear Growth Factor")

plt.legend()
plt.show()

# %%
import cosmology_amilly.linear_growth as lg
import numpy as np
import matplotlib.pyplot as plt

red_shifts = np.linspace(12, 0, 3000)
f_Standard = lg.Linear_Growth_Rate(red_shifts, 1, 0, 0, 0)
f_Lambda = lg.Linear_Growth_Rate(red_shifts, 0.3, 0, 0.7, 0)
f_Open = lg.Linear_Growth_Rate(red_shifts, 0.3, 0, 0, 0.7)

plt.figure(figsize=(6, 4))
plt.plot(1 + red_shifts, f_Standard, label="Standard CDM")
plt.plot(1 + red_shifts, f_Lambda, label="$\\Lambda$CDM")
plt.plot(1 + red_shifts, f_Open, label="Open CDM")

plt.xlabel("$1 + z$")
plt.ylabel("Linear Growth rate $f(z)$")
plt.xscale("log")
plt.xlim(1, 11)

plt.tick_params(axis="both", direction="in", length=8, width=1.5, top=True, right=True)
plt.tick_params(
    which="minor", direction="in", length=3, width=0.5, top=True, right=True
)
plt.grid(which="major", alpha=0.5)
plt.grid(which="minor", alpha=0.3)
plt.title("Linear Growth Rate")

plt.legend()
plt.tight_layout()
plt.show()
